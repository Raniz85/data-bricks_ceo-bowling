# %% [markdown]
# Eve Stermball won with a total score of 790. Impressive!
#
# Satisfied with your work you quickly return to your other duties. After a few minutes, you get a call from your manager requiring your help. Apparently your CEO is furious because he didn't win.
#
# Discussing with your manager you decide to alter the rules a bit for the next bowling series:
#
# * If all ten pins are downed on the first roll it is deemed a strike and grants 10 points
# * If all ten pins are downed by the second roll it is deemed a spare and grants 5 points
#
# With these new rules, let's return to the example and calculate new scores:
#
# ```
# Yatas Del Lana 3 5 3 5 7 2 3 0 10 4 3
# Eve Stojbs 3 7 3 3 9 1 6 4 2 3 1 0
# ```
#
# Dividing this up in frames we get:
#
# ```
# Yatas Del Lana | 3 5 | 3 5 | 7 2 | 3 0 | 10  | 4 3
# Eve Stojbs      | 3 7 | 3 3 | 9 1 | 6 4 | 2 3 | 1 0
# ```
#
# Summing up the scores according to the new rules you arrive at:
#
# * Yatas Delana: 3 + 5 + 3 + 5 + 7 + 2 + 3 + 0 + 10 + 4 + 3 + 10 (1 strike) = 55
# * Eve Stojbs: 3 + 7 + 3 + 3 + 9 + 1 + 6 + 4 + 2 + 3 + 1 + 0 + 3 × 5 (3 spares) = 57
#
# And according to these rules Eve Stojbs is the winner with 57 points.
#
# Satisfied with the rule changes you go back to your other duties. It doesn't take long for the next scorecard to arrive though - apparently your CEO called up everyone else and strongarmed them into another round of bowling as soon as he got your rule changes.
#
# Given the scores in the new series, calculate the winner and their score according to the revised rules.

# %%
from utils import load_input

input = load_input(2)

# %%
display(input)
